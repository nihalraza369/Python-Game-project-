# %%
import time
import random

print("⏱️ Welcome to the Reaction Time Tester Game!")
print("Get ready... When you see 'Now!', press Enter as fast as you can.")
print("Type 'exit' anytime to quit.")
print("-" * 50)

while True:
    ready = input("\nType 'go' to start or 'exit' to quit: ").lower()

    if ready == "exit":
        print("👋 Exiting game. Stay sharp!")
        break
    elif ready != "go":
        print("⚠️ Type 'go' to begin.")
        continue

    wait_time = random.randint(2, 5)
    print("⏳ Wait for it...")
    time.sleep(wait_time)

    print("👉 Now!")
    start_time = time.time()
    input()  # Wait for user to press Enter
    end_time = time.time()

    reaction_time = round(end_time - start_time, 3)
    print(f"⚡ Your reaction time: {reaction_time} seconds")
# Out:
# ⏱️ Welcome to the Reaction Time Tester Game!
# Get ready... When you see 'Now!', press Enter as fast as you can.
# Type 'exit' anytime to quit.
# --------------------------------------------------
#
# Type 'go' to start or 'exit' to quit: go
# ⏳ Wait for it...
# 👉 Now!
# g
# ⚡ Your reaction time: 0.614 seconds
#
# Type 'go' to start or 'exit' to quit: go
# ⏳ Wait for it...
# 👉 Now!
# g
# ⚡ Your reaction time: 0.696 seconds
#
# Type 'go' to start or 'exit' to quit: go
# ⏳ Wait for it...
# 👉 Now!
# d
# ⚡ Your reaction time: 0.624 seconds
#
# Type 'go' to start or 'exit' to quit: go
# ⏳ Wait for it...
# 👉 Now!
# f
# ⚡ Your reaction time: 0.62 seconds
#
# Type 'go' to start or 'exit' to quit: go
# ⏳ Wait for it...
# 👉 Now!
# d
# ⚡ Your reaction time: 1.278 seconds
#
# Type 'go' to start or 'exit' to quit: go
# ⏳ Wait for it...
# 👉 Now!
# a
# ⚡ Your reaction time: 6.184 seconds
#
# Type 'go' to start or 'exit' to quit: go
# ⏳ Wait for it...
# 👉 Now!
# f
# ...
